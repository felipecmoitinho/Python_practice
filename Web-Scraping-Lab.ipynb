# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="350" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Extract information from a given web site
# -   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
df = pd.read_html(url, header = 0)[0]
df = pd.DataFrame(df)

# %% [markdown]
# Create a soup object

# %%
#your code goes here

# %% [markdown]
# Scrape the `Language name`, `Created By` `annual average salary`and `Learning Difficulty`.

# %%
#your code goes here
# Done by pandas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[169], line 4
#       1 #your code goes here
#       2 # Done by pandas
#       3 np.arange(0,len(df['Average Annual Salary']))
# ----> 4 df['Average Annual Salary'][0].replace('$','').as_type(int)
#
# AttributeError: 'str' object has no attribute 'as_type'

# %% [markdown]
# Create a _dataframe_ for scrapped data

# %%
#your code goes here
# Done by pandas
df.columns
df = pd.read_html(url, header = 0)[0]

print(len(df['Average Annual Salary']))

def remove_character(x):
    x_new = []
    for n in np.arange(0,len(x)):
        x[n] = x[n].replace('$','')
        x[n] = x[n].replace(' ','')
        x[n] = x[n].replace(',','')
    return x
# Out:
# 10

# %%
df_new = remove_character(df['Average Annual Salary'])
print(df)
# Out:
#    No.    Language                                 Created By  \
# 0    1      Python                           Guido van Rossum
# 1    2        Java                              James Gosling
# 2    3           R               Robert Gentleman, Ross Ihaka
# 3    4  Javascript                                   Netscape
# 4    5       Swift                                      Apple
# 5    6         C++                          Bjarne Stroustrup
# 6    7          C#                                  Microsoft
# 7    8         PHP                             Rasmus Lerdorf
# 8    9         SQL    Donald D. Chamberlin, Raymond F. Boyce.
# 9   10          Go  Robert Griesemer, Ken Thompson, Rob Pike.
#
#   Average Annual Salary Learning Difficulty
# 0                114383                Easy
# 1                101013                Easy
# 2                 92037                Hard
# 3                110981                Easy
# 4                130801                Easy
# 5                113865                Hard
# 6                 88726                Hard
# 7                 84727                Easy
# 8                 84793                Easy
# 9                 94082           Difficult
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace('$','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(' ','')
# C:\Users\felip\AppData\Local\Temp\ipykernel_17840\4115913940.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[n] = x[n].replace(',','')

# %%
print(df.dtypes)
print(df)
df['Average Annual Salary'] = (df['Average Annual Salary']).astype(int)
# Out:
# No.                       int64
# Language                 object
# Created By               object
# Average Annual Salary    object
# Learning Difficulty      object
# dtype: object
#    No.    Language                                 Created By  \
# 0    1      Python                           Guido van Rossum
# 1    2        Java                              James Gosling
# 2    3           R               Robert Gentleman, Ross Ihaka
# 3    4  Javascript                                   Netscape
# 4    5       Swift                                      Apple
# 5    6         C++                          Bjarne Stroustrup
# 6    7          C#                                  Microsoft
# 7    8         PHP                             Rasmus Lerdorf
# 8    9         SQL    Donald D. Chamberlin, Raymond F. Boyce.
# 9   10          Go  Robert Griesemer, Ken Thompson, Rob Pike.
#
#   Average Annual Salary Learning Difficulty
# 0                114383                Easy
# 1                101013                Easy
# 2                 92037                Hard
# 3                110981                Easy
# 4                130801                Easy
# 5                113865                Hard
# 6                 88726                Hard
# 7                 84727                Easy
# 8                 84793                Easy
# 9                 94082           Difficult

# %% [markdown]
# Save the scrapped data into a file named _popular-languages.csv_

# %%
df = df.sort_values(by='Average Annual Salary')

# %%
# your code goes here
df.to_csv('popular-languages.csv')

# %%
fig, ax = plt.subplots()
ax.bar(x = df['Language'], height = df['Average Annual Salary'])
plt.xlabel('Programing Language')
plt.ylabel('Number os users')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
